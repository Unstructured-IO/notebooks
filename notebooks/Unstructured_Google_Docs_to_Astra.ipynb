# %% [markdown]
# ## Embed your Google Drive Docs in a DataStax Astra Vector Database with Unstructured!

# %% [markdown]
# Author: Nina Lopatina from Unstructured
#
# Nina's X handle: [@NinaLopatina](https://x.com/ninalopatina)
#
# Nina's LinkedIn: https://www.linkedin.com/in/ninalopatina
#
# Last updated: 06.28.24

# %% [markdown]
# Do you have some files in Google Docs that you want to parse, embed, and import to your Astra DataBase for RAG? If so, this notebook will guide you through all the steps to do so!
#
# Here are the initial non-code steps:
#
# A. Sign up for your [Unstructured API key](https://app.unstructured.io/) with a 2 week free trial for up to 1000 documents. You can find your API credentials in your dashboard.
#
# B. Create a [Google Drive service acount](https://support.google.com/a/answer/7378726?hl=en) or find your json with your login info. Make sure you share the google drive directory your data is stored in with the service account email address.
#
# C. Sign up to get your [AstraDB](https://www.google.com/url?q=https%3A%2F%2Fwww.datastax.com%2Flp%2Fastra-registration) DB endpoint and token
#
# D. Decide on which embeddings to use, and obtain the appropriate API Token as needed (in this notebook we are using OpenAI for embedding generation).
#
# Set up the any private API keys in a .env file in your Google Drive
# _______________
#
#
#
#
# 1. Now starting with the code below, we will install all the necessary libraries

# %%
# !pip install unstructured[all-docs] unstructured[astra] unstructured[openai] unstructured[embed-huggingface] langchain-community httpx python-dotenv
# Out:
# Collecting unstructured[all-docs]
#   Downloading unstructured-0.14.9-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.3 MB/s eta 0:00:00
# Collecting langchain-community
#   Downloading langchain_community-0.2.6-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 23.1 MB/s eta 0:00:00
# Collecting httpx
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 3.6 MB/s eta 0:00:00
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (5.2.0)
# Collecting filetype (from unstructured[all-docs])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting python-magic (from unstructured[all-docs])
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.9.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.8.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (0.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.31.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.12.3)
# Collecting emoji (from unstructured[all-docs])
#   Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 23.4 MB/s eta 0:00:00
# Collecting dataclasses-json (from unstructured[all-docs])
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting python-iso639 (from unstructured[all-docs])
#   Downloading python_iso639-2024.4.27-py3-none-any.whl (274 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.7/274.7 kB 8.7 MB/s eta 0:00:00
# Collecting langdetect (from unstructured[all-docs])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 10.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.25.2)
# Collecting rapidfuzz (from unstructured[all-docs])
#   Downloading rapidfuzz-3.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 17.8 MB/s eta 0:00:00
# Collecting backoff (from unstructured[all-docs])
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.12.2)
# Collecting unstructured-client (from unstructured[all-docs])
#   Downloading unstructured_client-0.23.8-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (1.14.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (4.66.4)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.1.4)
# Collecting pillow-heif (from unstructured[all-docs])
#   Downloading pillow_heif-0.16.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 58.0 MB/s eta 0:00:00
# Collecting pdf2image (from unstructured[all-docs])
#   Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Collecting pikepdf (from unstructured[all-docs])
#   Downloading pikepdf-9.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.0.3)
# Collecting google-cloud-vision (from unstructured[all-docs])
#   Downloading google_cloud_vision-3.7.2-py2.py3-none-any.whl (459 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.6/459.6 kB 21.8 MB/s eta 0:00:00
# Requirement already satisfied: xlrd in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (2.0.1)
# Collecting unstructured.pytesseract>=0.3.12 (from unstructured[all-docs])
#   Downloading unstructured.pytesseract-0.3.12-py3-none-any.whl (14 kB)
# Collecting pypdf (from unstructured[all-docs])
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.6)
# Collecting unstructured-inference==0.7.36 (from unstructured[all-docs])
#   Downloading unstructured_inference-0.7.36-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 3.4 MB/s eta 0:00:00
# Collecting pypandoc (from unstructured[all-docs])
#   Downloading pypandoc-1.13-py3-none-any.whl (21 kB)
# Collecting effdet (from unstructured[all-docs])
#   Downloading effdet-0.4.1-py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.5/112.5 kB 8.8 MB/s eta 0:00:00
# Collecting python-docx>=1.1.2 (from unstructured[all-docs])
#   Downloading python_docx-1.1.2-py3-none-any.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from unstructured[all-docs]) (3.3)
# Collecting pytesseract (from unstructured[all-docs])
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Collecting python-oxmsg (from unstructured[all-docs])
#   Downloading python_oxmsg-0.0.1-py3-none-any.whl (31 kB)
# Collecting python-pptx<=0.6.23 (from unstructured[all-docs])
#   Downloading python_pptx-0.6.23-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.6/471.6 kB 30.9 MB/s eta 0:00:00
# Collecting pdfminer.six (from unstructured[all-docs])
#   Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 42.4 MB/s eta 0:00:00
# Collecting onnx (from unstructured[all-docs])
#   Downloading onnx-1.16.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 40.2 MB/s eta 0:00:00
# Collecting layoutparser (from unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading layoutparser-0.3.4-py3-none-any.whl (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 37.4 MB/s eta 0:00:00
# Collecting python-multipart (from unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (0.23.4)
# Requirement already satisfied: opencv-python!=4.7.0.68 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (4.8.0.76)
# Collecting onnxruntime>=1.17.0 (from unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading onnxruntime-1.18.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 43.1 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (3.7.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (2.3.0+cu121)
# Collecting timm (from unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading timm-1.0.7-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 23.2 MB/s eta 0:00:00
# Requirement already satisfied: transformers>=4.25.1 in /usr/local/lib/python3.10/dist-packages (from unstructured-inference==0.7.36->unstructured[all-docs]) (4.41.2)
# Collecting astrapy (from unstructured[all-docs])
#   Downloading astrapy-1.3.1-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 9.4 MB/s eta 0:00:00
# Collecting tiktoken (from unstructured[all-docs])
#   Downloading tiktoken-0.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 26.8 MB/s eta 0:00:00
# Collecting openai (from unstructured[all-docs])
#   Downloading openai-1.35.7-py3-none-any.whl (327 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.5/327.5 kB 26.0 MB/s eta 0:00:00
# Collecting huggingface (from unstructured[all-docs])
#   Downloading huggingface-0.0.1-py3-none-any.whl (2.5 kB)
# Collecting sentence-transformers (from unstructured[all-docs])
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 17.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.9.5)
# Collecting langchain<0.3.0,>=0.2.6 (from langchain-community)
#   Downloading langchain-0.2.6-py3-none-any.whl (975 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 36.2 MB/s eta 0:00:00
# Collecting langchain-core<0.3.0,>=0.2.10 (from langchain-community)
#   Downloading langchain_core-0.2.10-py3-none-any.whl (332 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 23.7 MB/s eta 0:00:00
# Collecting langsmith<0.2.0,>=0.1.0 (from langchain-community)
#   Downloading langsmith-0.1.82-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (8.4.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx) (2024.6.2)
# Collecting httpcore==1.* (from httpx)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured[all-docs])
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 3.2 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured[all-docs])
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain<0.3.0,>=0.2.6->langchain-community)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.6->langchain-community) (2.7.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.10->langchain-community)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.10->langchain-community) (24.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.0->langchain-community)
#   Downloading orjson-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.0/145.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: Pillow>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx<=0.6.23->unstructured[all-docs]) (9.4.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx<=0.6.23->unstructured[all-docs])
#   Downloading XlsxWriter-3.2.0-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.9/159.9 kB 8.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured[all-docs]) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->unstructured[all-docs]) (2.0.7)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx) (1.2.1)
# Collecting bson<0.6.0,>=0.5.10 (from astrapy->unstructured[all-docs])
#   Downloading bson-0.5.10.tar.gz (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cassio<0.2.0,>=0.1.4 (from astrapy->unstructured[all-docs])
#   Downloading cassio-0.1.8-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 4.6 MB/s eta 0:00:00
# Collecting deprecation<2.2.0,>=2.1.0 (from astrapy->unstructured[all-docs])
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: toml<0.11.0,>=0.10.2 in /usr/local/lib/python3.10/dist-packages (from astrapy->unstructured[all-docs]) (0.10.2)
# Collecting uuid6<2024.2.0,>=2024.1.12 (from astrapy->unstructured[all-docs])
#   Downloading uuid6-2024.1.12-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->unstructured[all-docs]) (2.5)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from effdet->unstructured[all-docs]) (0.18.0+cu121)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from effdet->unstructured[all-docs]) (2.0.8)
# Collecting omegaconf>=2.0 (from effdet->unstructured[all-docs])
#   Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.9 MB/s eta 0:00:00
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (2.11.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (2.27.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (1.24.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-cloud-vision->unstructured[all-docs]) (3.20.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect->unstructured[all-docs]) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[all-docs]) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[all-docs]) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->unstructured[all-docs]) (2024.5.15)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->unstructured[all-docs]) (1.7.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->unstructured[all-docs]) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[all-docs]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[all-docs]) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->unstructured[all-docs]) (2024.1)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six->unstructured[all-docs]) (42.0.8)
# Collecting Pillow>=3.3.2 (from python-pptx<=0.6.23->unstructured[all-docs])
#   Downloading pillow-10.4.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 61.6 MB/s eta 0:00:00
# Collecting Deprecated (from pikepdf->unstructured[all-docs])
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting olefile (from python-oxmsg->unstructured[all-docs])
#   Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.6/114.6 kB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->unstructured[all-docs]) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->unstructured[all-docs]) (1.11.4)
# Collecting deepdiff>=6.0 (from unstructured-client->unstructured[all-docs])
#   Downloading deepdiff-7.0.1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.8/80.8 kB 9.4 MB/s eta 0:00:00
# Collecting jsonpath-python>=1.0.6 (from unstructured-client->unstructured[all-docs])
#   Downloading jsonpath_python-1.0.6-py3-none-any.whl (7.6 kB)
# Collecting mypy-extensions>=1.0.0 (from unstructured-client->unstructured[all-docs])
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: nest-asyncio>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from unstructured-client->unstructured[all-docs]) (1.6.0)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured[all-docs])
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.2 MB/s eta 0:00:00
# Collecting cassandra-driver<4.0.0,>=3.28.0 (from cassio<0.2.0,>=0.1.4->astrapy->unstructured[all-docs])
#   Downloading cassandra_driver-3.29.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.9/18.9 MB 40.9 MB/s eta 0:00:00
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (1.16.0)
# Collecting ordered-set<4.2.0,>=4.1.0 (from deepdiff>=6.0->unstructured-client->unstructured[all-docs])
#   Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.63.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision->unstructured[all-docs]) (1.48.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (4.9)
# Collecting h2<5,>=3 (from httpx)
#   Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.7.36->unstructured[all-docs]) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->unstructured-inference==0.7.36->unstructured[all-docs]) (2023.6.0)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.10->langchain-community)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf>=2.0->effdet->unstructured[all-docs])
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting coloredlogs (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (24.3.25)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (1.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->unstructured-inference==0.7.36->unstructured[all-docs]) (3.1.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.6->langchain-community) (2.18.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->unstructured-inference==0.7.36->unstructured[all-docs]) (0.4.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->unstructured-inference==0.7.36->unstructured[all-docs]) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->unstructured-inference==0.7.36->unstructured[all-docs]) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 50.9 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.25.1->unstructured-inference==0.7.36->unstructured[all-docs]) (0.19.1)
# Collecting iopath (from layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 4.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pdfplumber (from layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading pdfplumber-0.11.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers->unstructured[all-docs]) (3.5.0)
# Collecting geomet<0.3,>=0.1 (from cassandra-driver<4.0.0,>=3.28.0->cassio<0.2.0,>=0.1.4->astrapy->unstructured[all-docs])
#   Downloading geomet-0.2.1.post1-py3-none-any.whl (18 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six->unstructured[all-docs]) (2.22)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx)
#   Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx)
#   Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision->unstructured[all-docs]) (0.6.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 10.5 MB/s eta 0:00:00
# Collecting portalocker (from iopath->layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading portalocker-2.10.0-py3-none-any.whl (18 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->unstructured-inference==0.7.36->unstructured[all-docs]) (2.1.5)
# Collecting pypdfium2>=4.18.0 (from pdfplumber->layoutparser->unstructured-inference==0.7.36->unstructured[all-docs])
#   Downloading pypdfium2-4.30.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 13.4 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.17.0->unstructured-inference==0.7.36->unstructured[all-docs]) (1.3.0)
# Building wheels for collected packages: langdetect, bson, antlr4-python3-runtime, iopath
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993227 sha256=0008b21e72d3b1c0d33b33124a2c5acd030e4923e288e2bceb250890e2b7a086
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for bson (setup.py) ... done
#   Created wheel for bson: filename=bson-0.5.10-py3-none-any.whl size=11976 sha256=55ef165908e97edb764c06b2d3d742a60c5e95502a37c20c27b3aafd7e2444bc
#   Stored in directory: /root/.cache/pip/wheels/36/49/3b/8b33954dfae7a176009c4d721a45af56c8a9c1cdc3ee947945
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144554 sha256=723615de642628437d2b2bb3219fd4d2e23cddf00ffcfc5b5e2b89cd7264d2df
#   Stored in directory: /root/.cache/pip/wheels/12/93/dd/1f6a127edc45659556564c5730f6d4e300888f4bca2d4c5a88
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=afe6548f97cd03e607776613b799141bf0e7b9f2241f5059b91bb1c204449b42
#   Stored in directory: /root/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
# Successfully built langdetect bson antlr4-python3-runtime iopath
# Installing collected packages: huggingface, filetype, antlr4-python3-runtime, XlsxWriter, uuid6, rapidfuzz, python-multipart, python-magic, python-iso639, python-dotenv, python-docx, pypdfium2, pypdf, pypandoc, portalocker, Pillow, orjson, ordered-set, onnx, omegaconf, olefile, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, mypy-extensions, marshmallow, langdetect, jsonpointer, jsonpath-python, hyperframe, humanfriendly, hpack, h11, geomet, emoji, deprecation, Deprecated, backoff, unstructured.pytesseract, typing-inspect, tiktoken, requests-toolbelt, python-pptx, python-oxmsg, pytesseract, pillow-heif, pikepdf, pdf2image, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jsonpatch, iopath, httpcore, h2, deepdiff, coloredlogs, cassandra-driver, bson, pdfminer.six, onnxruntime, nvidia-cusolver-cu12, langsmith, httpx, dataclasses-json, cassio, unstructured-client, pdfplumber, openai, langchain-core, unstructured, sentence-transformers, layoutparser, langchain-text-splitters, google-cloud-vision, astrapy, timm, langchain, unstructured-inference, langchain-community, effdet
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.4.0 which is incompatible.
# Successfully installed Deprecated-1.2.14 Pillow-10.4.0 XlsxWriter-3.2.0 antlr4-python3-runtime-4.9.3 astrapy-1.3.1 backoff-2.2.1 bson-0.5.10 cassandra-driver-3.29.1 cassio-0.1.8 coloredlogs-15.0.1 dataclasses-json-0.6.7 deepdiff-7.0.1 deprecation-2.1.0 effdet-0.4.1 emoji-2.12.1 filetype-1.2.0 geomet-0.2.1.post1 google-cloud-vision-3.7.2 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.5 httpx-0.27.0 huggingface-0.0.1 humanfriendly-10.0 hyperframe-6.0.1 iopath-0.1.10 jsonpatch-1.33 jsonpath-python-1.0.6 jsonpointer-3.0.0 langchain-0.2.6 langchain-community-0.2.6 langchain-core-0.2.10 langchain-text-splitters-0.2.2 langdetect-1.0.9 langsmith-0.1.82 layoutparser-0.3.4 marshmallow-3.21.3 mypy-extensions-1.0.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 olefile-0.47 omegaconf-2.3.0 onnx-1.16.1 onnxruntime-1.18.1 openai-1.35.7 ordered-set-4.1.0 orjson-3.10.5 pdf2image-1.17.0 pdfminer.six-20231228 pdfplumber-0.11.1 pikepdf-9.0.0 pillow-heif-0.16.0 portalocker-2.10.0 pypandoc-1.13 pypdf-4.2.0 pypdfium2-4.30.0 pytesseract-0.3.10 python-docx-1.1.2 python-dotenv-1.0.1 python-iso639-2024.4.27 python-magic-0.4.27 python-multipart-0.0.9 python-oxmsg-0.0.1 python-pptx-0.6.23 rapidfuzz-3.9.3 requests-toolbelt-1.0.0 sentence-transformers-3.0.1 tiktoken-0.7.0 timm-1.0.7 typing-inspect-0.9.0 unstructured-0.14.9 unstructured-client-0.23.8 unstructured-inference-0.7.36 unstructured.pytesseract-0.3.12 uuid6-2024.1.12

# %% [markdown]
# 2. [Mount your Google drive locally](https://colab.research.google.com/notebooks/io.ipynb) -- there will be a pop up asking you to connect to your google drive -- to load your dotenv file, and to store your .json locally in case you want to reference them later.
#
#   The files themselves will be pulled via a connector to a service account, which allows for processing of google doc files in addition to standard file formats that can be saved in your Drive.
#
#   The secret parameters to set in your .env file are:
#
#   UNSTRUCTURED_API_KEY
#
#   UNSTRUCTURED_PARTITION_ENDPOINT
#
#   ASTRA_DB_TOKEN
#
#   ASTRA_DB_ENDPOINT

# %% [markdown]
# ### Note that in this notebook, you are sharing your Google Drive with the colab notebook itself, not with Unstructured or Weaviate.
#   If you prefer not to share your notebook, you can access your .env and Drive .json files in another fashion, e.g. by downloading this notebook as a .ipynb and running it locally with local directory access.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import dotenv

dotenv.load_dotenv('/content/drive/MyDrive/.env')
# Out:
# True

# %% [markdown]
# 3. We will set additional parameters here, that are not secret, that we can modify more easily in a notebook

# %%
os.environ['GCP_INGEST_SERVICE_KEY_FILE'] = '/content/drive/MyDrive/secret/your-account-key-json-here.json' # The json you downloaded for your account key
os.environ['GOOGLE_DRIVE_FOLDER_ID'] = 'your-folder-id-here' # The folder where your unstructured data is contained
os.environ['COLLECTION_NAME'] = 'podcast_VDB'
os.environ['EMBEDDING_DIMENSION'] = '384' #This value depends on the embedding model you choose. For our current default model per provider, the current values are 384 for HF and 1536 for OpenAI

# %% [markdown]
# #### Note that we temporarily have a bug in processing Docs, Sheets, and Slides in Google Docs (.doc, .xlsx, .ppt, etc., would work fine) -- as a temporary workaround, you can use the V1 SDK code, or download and upload your files)

# %% [markdown]
# 4. Set up Unstructured API access and process the documents as per our [Google Drive source connector](https://docs.unstructured.io/open-source/ingest/source-connectors/google-drive) documentation and set up the [Astra destination connector](https://docs.unstructured.io/open-source/ingest/destination-connectors/astra). Note that these will shortly be updated to for our new Serverless API.
#
#   At the end of this workflow, your unstructured documents have been extracted, chunked, summarized, embedded, and loaded in your Astra DB!

# %%
#All of the imports
from unstructured.ingest.v2.interfaces import ProcessorConfig
from unstructured.ingest.v2.pipeline.pipeline import Pipeline
from unstructured.ingest.v2.processes.chunker import ChunkerConfig
from unstructured.ingest.v2.processes.connectors.google_drive import (
    GoogleDriveAccessConfig,
    GoogleDriveIndexerConfig,
    GoogleDriveConnectionConfig,
    GoogleDriveDownloaderConfig,
)
from unstructured.ingest.v2.processes.connectors.astra import (
    AstraUploaderConfig,
    AstraConnectionConfig,
    AstraAccessConfig,
    AstraUploadStagerConfig,
)
import os

from unstructured.ingest.v2.processes.embedder import EmbedderConfig
from unstructured.ingest.v2.processes.partitioner import PartitionerConfig

# %%
Pipeline.from_configs(
    context=ProcessorConfig(tqdm=True, reprocess=True, verbose=False),
    source_connection_config=GoogleDriveConnectionConfig(
        access_config=GoogleDriveAccessConfig(
            service_account_key=os.getenv("GCP_INGEST_SERVICE_KEY_FILE"),
        ),
        drive_id = os.getenv("GOOGLE_DRIVE_FOLDER_ID"),
    ),
    indexer_config=GoogleDriveIndexerConfig(),
    downloader_config=GoogleDriveDownloaderConfig(),
    partitioner_config=PartitionerConfig(
        strategy="fast", #"hi_res" #for  images
        api_key=os.getenv("UNSTRUCTURED_API_KEY"),
        partition_by_api=True,
        partition_endpoint=os.getenv("UNSTRUCTURED_PARTITION_ENDPOINT"),
        ),
    chunker_config=ChunkerConfig(chunking_strategy="by_title"),
    embedder_config=EmbedderConfig(embedding_provider="langchain-huggingface"),
    destination_connection_config=AstraConnectionConfig(
        access_config=AstraAccessConfig(
            token=os.getenv("ASTRA_DB_TOKEN"), api_endpoint=os.getenv("ASTRA_DB_ENDPOINT")
        )
    ),
    stager_config=AstraUploadStagerConfig(),
    uploader_config=AstraUploaderConfig(
        collection_name=os.getenv("COLLECTION_NAME"),
        embedding_dimension=int(os.getenv("EMBEDDING_DIMENSION")),
        requested_indexing_policy={"deny": ["metadata"]},
    ),
).run()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1ca8cef3fc3e> in <cell line: 1>()
# ----> 1 Pipeline.from_configs(
#       2     context=ProcessorConfig(tqdm=True, reprocess=True, verbose=False),
#       3     source_connection_config=GoogleDriveConnectionConfig(
#       4         access_config=GoogleDriveAccessConfig(
#       5             service_account_key=os.getenv("GCP_INGEST_SERVICE_KEY_FILE"),
#
# NameError: name 'Pipeline' is not defined
# 2024-06-28 19:33:26,016 MainProcess INFO     Created index with configs: {"extensions": null, "recursive": false}, connection configs: {"access_config": "***REDACTED***", "drive_id": "1cF_wp5Mkuiyvrcee0KKBWWmLcyPj8BiP"}
# 2024-06-28 19:33:26,021 MainProcess INFO     Created download with configs: {"download_dir": null}, connection configs: {"access_config": "***REDACTED***", "drive_id": "1cF_wp5Mkuiyvrcee0KKBWWmLcyPj8BiP"}
# 2024-06-28 19:33:26,026 MainProcess INFO     Created partition with configs: {"strategy": "fast", "ocr_languages": null, "encoding": null, "additional_partition_args": null, "skip_infer_table_types": null, "fields_include": ["element_id", "text", "type", "metadata", "embeddings"], "flatten_metadata": false, "metadata_exclude": [], "metadata_include": [], "partition_endpoint": "https://api.unstructuredapp.io", "partition_by_api": true, "api_key": "*******", "hi_res_model_name": null}
# 2024-06-28 19:33:26,031 MainProcess INFO     Created chunk with configs: {"chunking_strategy": "by_title", "chunking_endpoint": "https://api.unstructured.io/general/v0/general", "chunk_by_api": false, "chunk_api_key": null, "chunk_combine_text_under_n_chars": null, "chunk_include_orig_elements": null, "chunk_max_characters": null, "chunk_multipage_sections": null, "chunk_new_after_n_chars": null, "chunk_overlap": null, "chunk_overlap_all": null}
# 2024-06-28 19:33:26,035 MainProcess INFO     Created embed with configs: {"embedding_provider": "langchain-huggingface", "embedding_api_key": null, "embedding_model_name": null, "embedding_aws_access_key_id": null, "embedding_aws_secret_access_key": null, "embedding_aws_region": null}
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:139: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 0.3.0. An updated version of the class exists in the langchain-huggingface package and should be used instead. To use it run `pip install -U langchain-huggingface` and import as `from langchain_huggingface import HuggingFaceEmbeddings`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 2024-06-28 19:33:39,703 MainProcess INFO     Created upload_stage with configs: {}
# 2024-06-28 19:33:39,706 MainProcess INFO     Created upload with configs: {"collection_name": "podcast_VDB", "embedding_dimension": 384, "namespace": null, "requested_indexing_policy": {"deny": ["metadata"]}, "batch_size": 20}, connection configs: {"access_config": "***REDACTED***", "connection_type": "astra"}
# 2024-06-28 19:33:39,710 MainProcess INFO     Running local pipline: index (GoogleDriveIndexer) -> download (GoogleDriveDownloader) -> partition (fast) -> chunk (by_title) -> embed (langchain-huggingface) -> upload_stage (AstraUploadStager) -> upload (AstraUploader) with configs: {"reprocess": true, "verbose": false, "tqdm": true, "work_dir": "/root/.cache/unstructured/ingest/pipeline", "num_processes": 2, "max_connections": null, "raise_on_error": false, "disable_parallelism": false, "preserve_downloads": false, "download_only": false, "max_docs": null, "re_download": false, "uncompress": false, "status": {}, "semaphore": null}
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# 2024-06-28 19:33:40,939 MainProcess INFO     Calling DownloadStep with 45 docs
# 2024-06-28 19:33:40,945 MainProcess INFO     processing content async
# 2024-06-28 19:33:40,949 MainProcess WARNING  async code being run in dedicated thread pool to not conflict with existing event loop: <_UnixSelectorEventLoop running=True closed=False debug=False>
# download: 100%|██████████| 45/45 [00:00<00:00, 133.10it/s]
# 2024-06-28 19:33:41,309 MainProcess INFO     DownloadStep [cls] took 0.37049055099487305 seconds
# 2024-06-28 19:33:41,311 MainProcess INFO     Calling PartitionStep with 45 docs
# 2024-06-28 19:33:41,313 MainProcess INFO     processing content async
# 2024-06-28 19:33:41,315 MainProcess WARNING  async code being run in dedicated thread pool to not conflict with existing event loop: <_UnixSelectorEventLoop running=True closed=False debug=False>
# partition:   0%|          | 0/45 [00:00<?, ?it/s]INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# partition:   2%|▏         | 1/45 [00:03<02:24,  3.27s/it]INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# partition:   4%|▍         | 2/45 [00:05<02:02,  2.86s/it]INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# partition:  11%|█         | 5/45 [00:06<00:36,  1.08it/s]INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# partition:  20%|██        | 9/45 [00:08<00:19,  1.86it/s]INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# partition:  24%|██▍       | 11/45 [00:09<00:20,  1.63it/s]INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# partition:  29%|██▉       | 13/45 [00:11<00:22,  1.40it/s]INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# partition:  36%|███▌      | 16/45 [00:15<00:29,  1.01s/it]INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# partition:  49%|████▉     | 22/45 [00:16<00:10,  2.23it/s]INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# partition:  53%|█████▎    | 24/45 [00:17<00:09,  2.21it/s]INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Successfully partitioned the document.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# partition:  67%|██████▋   | 30/45 [00:20<00:06,  2.36it/s]INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# partition:  71%|███████   | 32/45 [00:22<00:07,  1.72it/s]INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Preparing to split document for partition.
# INFO: Given file doesn't have '.pdf' extension, so splitting is not enabled.
# INFO: Partitioning without split.
# INFO: Successfully partitioned the document.
# partition:  73%|███████▎  | 33/45 [00:25<00:11,  1.09it/s]INFO: Successfully partitioned the document.
# INFO: Successfully partitioned the document.
# partition:  76%|███████▌  | 34/45 [00:28<00:14,  1.32s/it]INFO: Successfully partitioned the document.
# partition:  78%|███████▊  | 35/45 [00:29<00:11,  1.17s/it]INFO: Successfully partitioned the document.
# partition: 100%|██████████| 45/45 [00:30<00:00,  1.47it/s]
# 2024-06-28 19:34:11,964 MainProcess INFO     PartitionStep [cls] took 30.6538245677948 seconds
# INFO: PartitionStep [cls] took 30.6538245677948 seconds
# 2024-06-28 19:34:11,967 MainProcess INFO     Calling ChunkStep with 45 docs
# INFO: Calling ChunkStep with 45 docs
# 2024-06-28 19:34:11,971 MainProcess INFO     processing content across processes
# INFO: processing content across processes
# chunk: 100%|██████████| 45/45 [00:35<00:00,  1.28it/s]
# 2024-06-28 19:34:47,490 MainProcess INFO     ChunkStep [cls] took 35.52258920669556 seconds
# INFO: ChunkStep [cls] took 35.52258920669556 seconds
# 2024-06-28 19:34:47,496 MainProcess INFO     Calling EmbedStep with 45 docs
# INFO: Calling EmbedStep with 45 docs
# 2024-06-28 19:34:47,502 MainProcess INFO     processing content across processes
# INFO: processing content across processes
# embed: 100%|██████████| 45/45 [03:36<00:00,  4.82s/it]
# 2024-06-28 19:38:24,496 MainProcess INFO     EmbedStep [cls] took 216.99979853630066 seconds
# INFO: EmbedStep [cls] took 216.99979853630066 seconds
# 2024-06-28 19:38:24,502 MainProcess INFO     Calling UploadStageStep with 45 docs
# INFO: Calling UploadStageStep with 45 docs
# 2024-06-28 19:38:24,508 MainProcess INFO     processing content across processes
# INFO: processing content across processes
# upload_stage: 100%|██████████| 45/45 [00:03<00:00, 11.39it/s]
# 2024-06-28 19:38:28,571 MainProcess INFO     UploadStageStep [cls] took 4.068871974945068 seconds
# INFO: UploadStageStep [cls] took 4.068871974945068 seconds
# 2024-06-28 19:38:28,576 MainProcess INFO     Calling UploadStep with 45 docs
# INFO: Calling UploadStep with 45 docs
# 2024-06-28 19:38:29,549 MainProcess INFO     writing 3124 objects to destination collection podcast_VDB
# INFO: writing 3124 objects to destination collection podcast_VDB
# INFO: ASTRA_DB_KEYSPACE is not set. Defaulting to 'default_keyspace'
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://66cc4357-da0e-4408-8a74-e34cbf94b33d-us-east-2.apps.astra.datastax.com/api/json/v1/default_keyspace/podcast_VDB "HTTP/1.1 200 OK"
# 2024-06-28 19:38:49,508 MainProcess INFO     UploadStep [cls] took 20.93224024772644 seconds
# INFO: UploadStep [cls] took 20.93224024772644 seconds
# 2024-06-28 19:38:49,516 MainProcess INFO     Finished ingest process in 309.8064422607422s
# INFO: Finished ingest process in 309.8064422607422s
